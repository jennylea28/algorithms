# %% [markdown]
# # Algorithms 202: Coursework 2 Task 1: Random Sampling

# %% [markdown]
# Group-ID: XX

# %% [markdown]
# Group members: ADD NAMES HERE

# %% [markdown]
# ## Objectives

# %% [markdown]
# The aim of this coursework is to enhance your algorithmic skills by developing algorithms from textual, non-formal descriptions. You are asked to show that you can:
#
# - implement three different random sampling algorithms
# - compare those algorithms using visual representations based on image sampling
#
# This notebook *is* the coursework. It contains cells with function definitions that you will need to complete. You will submit this notebook as your coursework.

# %% [markdown]
# ## Preliminaries: helper functions

# %% [markdown]
# Here we define a collection of functions that will be useful for the rest of the coursework. You'll need to run this cell to get started.

# %%
# %matplotlib inline
import numpy as np
from scipy.ndimage import map_coordinates
from scipy.spatial import cKDTree as KDTree
from matplotlib import pyplot as plt
from PIL import Image

def load_image(path):
    return np.array(Image.open(str(path)))

def sample_colors(image, sample_points):
    r"""
    Sample RGB colour values from an image of shape (w, h, 3)
    at floating point (x, y) sample points.
    """
    r = map_coordinates(image[..., 0], sample_points.T)
    g = map_coordinates(image[..., 1], sample_points.T)
    b = map_coordinates(image[..., 2], sample_points.T)
    return np.vstack((r, g, b)).T

def indices_of_pixels(image):
    r"""(x, y) index values for each pixel in an image.
    """
    return np.indices(image.shape[:2]).reshape([2, -1]).T

def closest_index(sample_points, indices):
    r"""
    Find the nearest sample_point at a given index
    (along with the distance to the point). Input is
    an array of sample_points and an array of indicies to
    test at. Output is array of indices and distances.
    """
    kdtree = KDTree(sample_points)
    distance, index = kdtree.query(indices)
    return index, distance

def resample_image(image, sample_points):
    # for each (floating point) sample_point extract the
    # RGB colour value of the image at that location
    colors = sample_colors(image, sample_points)
    # get all (x, y) index values for each pixel in
    # the image
    indices = indices_of_pixels(image)
    # for every pixel (each index) find the nearest sample
    # point (and the distance, but we don't need it here)
    c_index,_ = closest_index(sample_points, indices)
    # map the closest indexes to colour values - reshape
    # the resulting RGB array back into the original image 
    # shape.
    return colors[c_index].reshape(image.shape)
# Out:
# /Users/jennylea/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# ## Task 1: Random Sampling

# %% [markdown]
# In this task you are asked to implement `uniform_sampling`, `best_candidate_sampling` and `poison_disc_sampling`. Additionally, you will need to implement visualising techniques that can be used to compare the output of the three different random sampling algorithms.
#
# Complete the below function definitions in the provided skeleton code. Do not change the names of the functions or their arguments.

# %% [markdown]
# ### 1a. Implement `uniform_sampling`

# %% [markdown]
# The `uniform_sampling` function should produce `n_samples` sample points randomly distributed over the sample domain. See lecture slides for details and pseudo-code. Hint: The sample domain defined by the width and the height of the image can be obtained by `image.shape[:2]`.

# %%
import random

def uniform_sample(w, h):
    return(random.uniform(0, w), random.uniform(0, h))

def uniform_sampling(image, n_samples):
    samples = []
    
    # dimensions is a tuple of width and height
    dimensions = image.shape[:2]
    
    for i in range(n_samples):
        #sample = [random.random() * dimensions[0], random.random() * dimensions[1]]
        #sample = [random.uniform(0, dimensions[0]), random.uniform(0, dimensions[1])]
        samples.append(uniform_sample(dimensions[0], dimensions[1]))
    return samples

image = load_image('./mandrill.png')
uniform_sampling(image, 685)
# Out:
# [(302.6197889157305, 359.39940264007913),
#  (114.44084320093768, 207.71855885726288),
#  (280.91331674242974, 379.45830322739874),
#  (88.75088023739771, 67.15050193919708),
#  (392.54159055972207, 475.7163902765782),
#  (393.3814622818394, 77.67228079861238),
#  (351.9853160825152, 417.0778166357046),
#  (453.02326040614537, 183.34002699097002),
#  (49.959225658814574, 256.23188553991804),
#  (253.63325119358626, 196.82062173045674),
#  (434.9210425300411, 398.06194294700117),
#  (21.417951592097406, 437.4248679362519),
#  (93.96100060033378, 275.05711789992137),
#  (317.3996034241337, 452.67221160711676),
#  (407.05565699315315, 344.6023771402528),
#  (66.65589976991743, 105.42570704671267),
#  (224.49284117373432, 270.7262046599389),
#  (74.11096474942768, 102.00312040603588),
#  (276.52541894178376, 456.5171644416039),
#  (454.743882428649, 166.30511474868516),
#  (313.80957737915634, 249.82455149162575),
#  (457.4562766285505, 187.61755478764118),
#  (92.43426063852012, 435.52000432611015),
#  (389.0545318785916, 402.4794399561004),
#  (347.84394956283916, 259.3904630662719),
#  (388.2575522450726, 488.28608423549355),
#  (197.78780426572484, 266.4611718370708),
#  (125.0789742634017, 370.92642832009267),
#  (186.12799338597054, 397.79878206593185),
#  (76.13593166341538, 336.1875403886237),
#  (352.70870026655643, 97.09150152093132),
#  (99.66152393510896, 488.5931380179202),
#  (37.724264487227614, 62.22480857345286),
#  (192.0808417692674, 265.75955200476204),
#  (268.56570745589994, 255.97372460225338),
#  (172.80660028044383, 406.5691441193235),
#  (127.31744442941172, 43.60238345854933),
#  (351.6632767627818, 439.6679027524151),
#  (1.391428396554737, 303.53478354346174),
#  (435.6274272202087, 119.0628210487722),
#  (411.38671312749705, 315.17829242726935),
#  (94.24975265947123, 9.958733399406617),
#  (471.01892027803257, 417.77429595434495),
#  (302.5889420128823, 389.6623912323734),
#  (281.887926628602, 399.1125113832859),
#  (341.8861056071632, 469.91009461292714),
#  (301.97926839252443, 251.67499892818606),
#  (271.4222234631945, 234.17496775888995),
#  (239.97055896047297, 139.08384786952405),
#  (344.1560309449687, 422.83439805945324),
#  (224.9904473916072, 373.4293688623852),
#  (59.08136809042233, 290.91639949964326),
#  (231.35716538613786, 71.69549556460203),
#  (33.52743780308014, 312.63618145676384),
#  (396.7269222564697, 190.66052214380673),
#  (146.53865856710763, 37.50086858470914),
#  (379.0849411634282, 8.819933667967517),
#  (20.18441178937632, 451.6763003346149),
#  (25.114908164062744, 355.7865585866559),
#  (73.29342845942179, 242.69602404682706),
#  (287.58204568754076, 158.4544828963531),
#  (322.81377897005643, 339.4009753555957),
#  (362.8765171517866, 142.77246139055023),
#  (75.99583115430511, 482.46742977226216),
#  (264.19494964329374, 147.2227409519427),
#  (250.3902083231913, 218.02668812815097),
#  (248.22433298865883, 370.1768326573263),
#  (56.985654534932806, 460.58897467911333),
#  (4.170802841919485, 392.8660803990636),
#  (15.896634413344266, 300.8512118763643),
#  (157.10048144510216, 208.440663568216),
#  (146.91547140552785, 192.92378133625948),
#  (416.2677593014965, 258.54072549668217),
#  (465.2869368055536, 9.268140807748459),
#  (291.83563692335247, 267.0653869955053),
#  (343.13416889684987, 79.21595620007011),
#  (286.72096309162606, 53.53420577167706),
#  (69.98798619481067, 41.0353641974856),
#  (26.11756262852932, 32.271034584408),
#  (186.25810223345655, 370.33080497662627),
#  (417.68076944402475, 493.7366016697877),
#  (73.01386906406387, 264.8320473094792),
#  (197.86212032891348, 389.16870940369836),
#  (62.40390506412338, 460.6412228914304),
#  (193.81449684868915, 441.90743870990565),
#  (473.8750964129512, 26.482126548800778),
#  (92.08632014256209, 388.57399517794784),
#  (0.8022351052583332, 360.83292765560674),
#  (58.01315931041101, 411.63573092832587),
#  (346.7002419533837, 209.2016138802319),
#  (212.1009763582265, 166.36160654950677),
#  (313.171576086559, 428.6902498230453),
#  (105.34277314562124, 471.4750923335553),
#  (346.1745862367814, 55.93432142906568),
#  (456.72179569595534, 455.38643620715976),
#  (125.31346901651068, 497.3262197999193),
#  (74.88576812361076, 133.70286591755598),
#  (232.5816802425458, 477.14325881403295),
#  (30.5931141223963, 111.40356023238846),
#  (344.4569197270137, 215.14247050315927),
#  (71.4265586031256, 186.10426336986285),
#  (200.58399136555056, 359.29116388361115),
#  (368.5897013777125, 344.7875278252829),
#  (243.95073996852983, 104.70943780523167),
#  (141.23061414013063, 217.00689502942765),
#  (226.50735912831726, 159.40117405440108),
#  (114.26867620036825, 393.1278744589735),
#  (451.0457379290155, 424.4007287477757),
#  (196.24835332413227, 336.76219231097207),
#  (374.3874821424221, 16.66326115145417),
#  (81.45484609882665, 461.5252809112006),
#  (144.1872598739381, 241.16130730577052),
#  (392.140422257382, 353.4913837786212),
#  (178.84833478948528, 412.53281067844694),
#  (182.0224170950502, 451.6503146004003),
#  (375.0344282013098, 240.06858263871123),
#  (70.28132396758777, 466.9608296702949),
#  (318.26661416967784, 190.1284693556487),
#  (186.09161420032257, 410.84000092707043),
#  (332.74763488033364, 138.62527880481667),
#  (182.6660813213578, 454.1726442704228),
#  (160.22036223657696, 461.7980113226382),
#  (151.31702408782724, 487.7242419861574),
#  (468.63955586505995, 328.369531897178),
#  (170.09324044094666, 283.9392302256146),
#  (135.88972305494843, 55.38874033003632),
#  (194.92380260689475, 386.4521231207716),
#  (93.0706500386117, 421.7385938130108),
#  (39.91126904883329, 112.55656426470628),
#  (164.958894114763, 398.4533371606326),
#  (188.39747501984627, 87.4404152227874),
#  (327.93523283528964, 28.37325422407766),
#  (175.17670832091622, 441.8331204368819),
#  (144.21887194021184, 73.54224967476236),
#  (283.99453769456034, 485.76123770829986),
#  (109.7405700459801, 103.03876108814237),
#  (43.776614320336655, 370.91000204515916),
#  (289.37820501743437, 157.8734463130831),
#  (270.19164370370396, 128.32335540648143),
#  (318.8759377058819, 1.3161504981627492),
#  (412.2845377028111, 44.67414095436939),
#  (124.64245184787211, 484.03235290426267),
#  (299.24641598030456, 68.8079285895477),
#  (45.991524045554385, 334.2517767300141),
#  (317.5616363754133, 181.1719409072885),
#  (212.43038309071625, 468.4504752635043),
#  (7.856272046394626, 483.95921592780985),
#  (28.034599808622307, 58.75083898002437),
#  (385.8190957167851, 25.61027446380931),
#  (171.35830895255535, 10.405868315061518),
#  (66.45772282832952, 169.72000855891366),
#  (470.97862364827256, 12.384194444812202),
#  (328.1336604679803, 271.3137985027037),
#  (393.73515846386726, 364.9508235198719),
#  (87.36136728665853, 31.55268571400266),
#  (205.41662463866635, 285.4598808864281),
#  (181.84228272631967, 140.39412275329255),
#  (311.6591731093997, 424.8067360803696),
#  (241.90067252984284, 351.2788018097123),
#  (348.885357629206, 180.96185431752681),
#  (218.03135563245132, 412.28383467673837),
#  (176.6858859984796, 440.3147602579922),
#  (237.15592400910575, 117.48052949315468),
#  (473.98306624234937, 319.4026569984105),
#  (422.3217870077208, 303.92862944804085),
#  (215.66841827936287, 314.9036602681723),
#  (389.05787575485004, 32.74935022313829),
#  (184.9628983728894, 332.0060035032572),
#  (393.1326181333097, 466.9098729046956),
#  (181.2290747728169, 99.59551856205067),
#  (286.319424197583, 82.12721138201445),
#  (465.6708271965009, 272.6740150351367),
#  (5.270858390294304, 22.652848483450505),
#  (308.4977150903303, 278.7021687689276),
#  (122.68906889242126, 136.44286115667092),
#  (369.0442524109846, 1.672881342959065),
#  (268.2050015257424, 135.29022280058624),
#  (43.52870272742521, 499.1099240061671),
#  (29.15024746824459, 155.69599853349004),
#  (44.554964958604714, 182.37873293666385),
#  (400.2768782918821, 183.42546253583603),
#  (321.8297642224464, 349.7418023544718),
#  (261.54665290519836, 68.35750927885148),
#  (363.15637394795476, 168.48989167138768),
#  (428.8589825003592, 433.12088513904615),
#  (185.88845308580002, 408.68941661785504),
#  (207.87579145418135, 468.972884205883),
#  (257.24329433075434, 72.6183506846541),
#  (187.63560015911304, 83.34527100917371),
#  (399.69911377821626, 315.13810235841197),
#  (229.54109141874525, 357.8921780902542),
#  (391.45303811134306, 35.981214398015545),
#  (61.568676538367875, 458.6840738427905),
#  (315.2487424322925, 285.88217393947116),
#  (405.137906111347, 228.36440503703577),
#  (270.26522905666263, 39.89250624472812),
#  (452.8577566401323, 129.68549502812076),
#  (316.98041040914995, 332.9322797666103),
#  (217.5532053119972, 496.0447009965221),
#  (444.73946259661216, 341.4752971154911),
#  (290.07099099165544, 379.9341694443812),
#  (250.68198984073763, 177.3306918953937),
#  (292.64539544278944, 330.9772374828631),
#  (381.75512391226147, 307.7973896452529),
#  (41.5019598331121, 178.1487070811466),
#  (171.85266344623108, 47.22980977869257),
#  (326.7330807420618, 374.8413660322869),
#  (185.39961284512384, 126.00973830291218),
#  (414.9947285826081, 181.16785823075915),
#  (443.9780923863119, 127.21195941253688),
#  (254.17095103454076, 357.35233204700086),
#  (441.8472982287721, 202.88096833630365),
#  (332.15132098876524, 343.4479059251553),
#  (203.64576851611443, 331.48074828514734),
#  (454.15769235717846, 237.9316432722014),
#  (86.40801940451257, 446.59837615867013),
#  (437.55397670942506, 245.11081985422985),
#  (349.54407047500143, 343.76261472302275),
#  (427.491119880899, 178.02668611666718),
#  (81.51948905110777, 327.11843682060106),
#  (133.52630956983103, 465.67799152462163),
#  (285.10260407911204, 122.8911392589866),
#  (183.33702884316938, 441.1782458703319),
#  (73.3073370309856, 338.1231275241161),
#  (355.45023679556823, 496.41280186092564),
#  (396.128868995084, 20.147383631523464),
#  (469.1115935342009, 439.1288172137485),
#  (112.68939967195563, 384.96009690526836),
#  (389.88135584678764, 468.4414030281641),
#  (63.691060760368586, 178.82754672424855),
#  (375.07646169763547, 146.08081912246305),
#  (269.7678896351674, 442.4609069149356),
#  (183.44922836904206, 225.60726750491267),
#  (459.111648818686, 297.95026474787636),
#  (6.342079286572915, 265.7801984237897),
#  (411.58196687142686, 87.50322422001383),
#  (322.0106337083395, 169.95690485745257),
#  (479.03307955329944, 213.92373168822527),
#  (62.28946775373366, 460.2301441772653),
#  (239.61303043786225, 438.3194610499489),
#  (273.1258892967198, 415.97044524397194),
#  (114.58496921569049, 39.14681880045373),
#  (292.52591506722354, 287.1814444811124),
#  (28.434688211757635, 119.67220700725362),
#  (274.3489355769617, 126.06056530818339),
#  (267.2295536822846, 382.57370520460194),
#  (122.27890464957584, 347.3527414128622),
#  (91.64176420299428, 199.6252703795439),
#  (367.03339250025846, 259.2718191656877),
#  (115.50143332256005, 253.73907650364856),
#  (93.63631236485206, 271.80812128966534),
#  (74.68753577604363, 191.53521638383037),
#  (298.3244303116298, 190.6921807959715),
#  (310.0997449785119, 389.05209658248043),
#  (333.898799978688, 396.20315727266063),
#  (163.60548417658907, 173.85419054112273),
#  (145.2739059034783, 119.03434003520658),
#  (222.1162063810672, 252.32648980698053),
#  (344.37364290729056, 488.6734553722573),
#  (385.5690030499557, 379.98532452299355),
#  (325.21848515161287, 139.83631850564953),
#  (265.099021232415, 156.36604150118848),
#  (248.82258120202275, 458.42218740869924),
#  (309.3061568903567, 51.40283642644727),
#  (150.60754479094362, 143.18619299626613),
#  (462.4581101878196, 364.4058797162171),
#  (163.27557616506726, 268.11372304494205),
#  (439.99736916399, 366.42382731086417),
#  (178.46116851382504, 230.41567740964192),
#  (425.91374989778717, 286.2031104690861),
#  (10.278627623685743, 350.03264534471174),
#  (83.03891287178485, 482.2903702963004),
#  (301.0787779502726, 336.88991314725433),
#  (199.9346657362919, 195.21292648510146),
#  (72.48147169413542, 206.50958279142733),
#  (362.3074008865011, 271.90237106776283),
#  (183.6121270139232, 379.20434128293255),
#  (352.443575389898, 371.5319948849155),
#  (83.00096019242666, 111.21299158528514),
#  (275.16656540548377, 59.00624041316283),
#  (367.3067973850968, 300.37153452556004),
#  (35.380144429967416, 204.36392208690734),
#  (250.69307882520033, 59.849389745804224),
#  (396.07551475316876, 50.92213762335612),
#  (453.96522272421544, 171.91230149887897),
#  (205.36472550295062, 109.44982143270666),
#  (76.48932176415828, 103.14611127374162),
#  (273.90344053907836, 395.2544594495222),
#  (265.00904549064137, 46.45628997433726),
#  (64.70014270907473, 49.460175541759746),
#  (229.34585340152265, 181.62962104751006),
#  (44.946479759577684, 217.57495655794244),
#  (0.9617018355481122, 365.7079112213236),
#  (9.74643947755025, 58.342232374925864),
#  (366.87546430965915, 167.0741238541647),
#  (347.45247148361676, 41.368035448727134),
#  (468.06081849939517, 94.80196681435449),
#  (235.6944434323424, 194.16257720766882),
#  (470.92390209573165, 376.2658983699225),
#  (185.8532989907415, 397.2693567755398),
#  (55.05053965341606, 163.79372925496483),
#  (37.902792371878746, 112.21340656019774),
#  (303.6046044465508, 216.3981809173013),
#  (334.65243166551005, 37.61802964651429),
#  (289.62723928670135, 209.6105805731621),
#  (379.68718432963396, 335.03481681779084),
#  (201.08539678496834, 480.5078737826217),
#  (102.55823747973794, 237.59141805353167),
#  (50.55530791439022, 394.5268464606485),
#  (54.15885834930896, 239.21078377150025),
#  (90.75508191863067, 31.525482598929177),
#  (372.61773330763515, 323.4752128052817),
#  (248.4303455980438, 234.04509098824633),
#  (214.6798429010588, 271.2372312282685),
#  (269.69536145671276, 54.90741118506648),
#  (340.0898598528895, 287.45305627608707),
#  (360.9284776934368, 52.37091928824961),
#  (459.1256375273608, 418.8781597270175),
#  (178.9695320130706, 265.76294385414957),
#  (392.08192719541915, 266.179154109646),
#  (439.33075341010374, 61.73076702796298),
#  (423.7489728480643, 370.647752921907),
#  (272.77818255242113, 419.3558965113812),
#  (167.23698787611227, 301.0363380226648),
#  (337.89522752730466, 74.99113710595412),
#  (168.57046284993095, 166.2780110450389),
#  (452.0672881922681, 11.196282706457506),
#  (315.0647924477102, 288.896895585877),
#  (326.8942962641758, 298.11709477497897),
#  (165.30766890719622, 423.74882236485615),
#  (188.42739611287504, 429.8352127669539),
#  (346.62250404746277, 374.24559467717535),
#  (384.1072792133188, 452.543527350192),
#  (471.0608943333938, 1.3027274560516444),
#  (229.4709148139215, 132.28081761045502),
#  (209.79302828832107, 89.91682956203285),
#  (67.5499452035902, 184.08920771837413),
#  (391.54791100649527, 95.43233923827071),
#  (79.30320282234354, 413.4046987575067),
#  (460.4492181458967, 241.32370970520117),
#  (159.53253719855095, 433.2236705245427),
#  (437.30353436742934, 251.01372202761684),
#  (417.45264393955915, 406.55166895478374),
#  (104.61481084440301, 327.1374012078726),
#  (470.7006762207748, 253.73905609706915),
#  (469.8780334874319, 197.15466932351356),
#  (365.21174706206887, 200.40796132491533),
#  (208.16266707062763, 35.24494536412559),
#  (452.8547987110433, 388.7233799460847),
#  (362.18841594190053, 351.6108377121506),
#  (340.80704981671335, 321.4692538198421),
#  (215.90197131876275, 72.99165318798961),
#  (241.7139015522344, 227.33078148854113),
#  (86.63141589755689, 387.5841582204011),
#  (16.018428803957416, 442.30937360700227),
#  (288.7451778824203, 121.34305517653394),
#  (233.65580887139666, 300.4420746139357),
#  (461.28872329835053, 490.8779575700812),
#  (95.91406416834589, 24.9086137288837),
#  (31.365916977975807, 116.58707725982909),
#  (44.20529680027501, 20.840583607105113),
#  (19.960065020284077, 268.17851069311666),
#  (148.74674311261452, 80.71244074734862),
#  (104.80269898268185, 221.245695643812),
#  (66.64743196902495, 450.3174660670365),
#  (443.80280384847146, 131.8383713228633),
#  (222.38295605240967, 179.18424132537157),
#  (25.839434340568577, 203.70307684085444),
#  (85.98510007503093, 408.2721537351304),
#  (463.8905738100797, 340.73721580382784),
#  (52.06740171633355, 386.3052350942202),
#  (71.78598543357407, 47.065496936096295),
#  (361.66106316377954, 410.5185463199117),
#  (355.0929480660043, 301.4090317996621),
#  (361.57530249365345, 155.26455027135515),
#  (35.6166419574161, 174.86866573975084),
#  (134.37746045381144, 405.57265888175795),
#  (97.73056293348033, 214.16538013007042),
#  (6.160477302793463, 285.4707791519243),
#  (106.20937204983719, 4.789831269734646),
#  (29.545267274805465, 51.13554044567748),
#  (323.90610940805493, 140.5764809956691),
#  (368.751186611441, 457.1782355932629),
#  (35.294726003766584, 199.85530387104967),
#  (6.03920953698962, 369.54293500766875),
#  (31.718090394259768, 89.17608570244656),
#  (408.18745617641173, 8.349904080561021),
#  (137.32994935689246, 329.2786810613122),
#  (167.00647463060935, 351.32890688598866),
#  (330.02173937390575, 97.76506900573139),
#  (108.17550635215449, 456.0651062702833),
#  (428.43400314883536, 83.11456267417039),
#  (357.2927769387003, 156.11255382936795),
#  (355.7442944036104, 194.81890416659385),
#  (100.76815134144678, 198.75972709418767),
#  (403.15632835444575, 170.77487849829078),
#  (466.10055303926316, 39.67186607534262),
#  (459.2288316134147, 474.68570044863327),
#  (283.26118307496273, 82.11410056337282),
#  (166.7878484292941, 397.57792246971366),
#  (139.86299274244936, 492.86782445049136),
#  (212.5557652957902, 450.629259252638),
#  (115.9352950995077, 281.0198943569128),
#  (333.15456803626955, 223.11513226293707),
#  (421.3475605830361, 373.98564582787594),
#  (145.86677399159316, 347.0866133663426),
#  (79.51853296790951, 481.91666958073114),
#  (401.6278796271644, 443.7687058917263),
#  (94.45555142653185, 1.7582357327455278),
#  (181.29193055879264, 344.6931237558516),
#  (63.662639974011284, 286.0365809779961),
#  (89.15990965662002, 6.650052312577037),
#  (158.02735495029788, 235.97901519493885),
#  (284.40264521240704, 242.88808134858485),
#  (467.05512901575895, 384.489442745528),
#  (387.27656322901527, 324.2311152275064),
#  (149.26602358922608, 301.22650141241144),
#  (454.92371991989125, 70.01442340678904),
#  (232.8900988510593, 192.38186117202548),
#  (247.86212003677952, 207.54650957162207),
#  (179.6121254794145, 262.10152795463057),
#  (208.66941349490642, 132.53693052202524),
#  (192.8636825187004, 242.47078360500635),
#  (20.42748084273878, 153.00803448075305),
#  (388.40571564931395, 346.825244823022),
#  (389.3151163792824, 417.9784811544494),
#  (192.22733197347898, 440.38137805554936),
#  (136.49339381317705, 356.394026131774),
#  (445.3960093860012, 224.29436934109205),
#  (475.0795146208227, 168.25709506172674),
#  (82.22866650044516, 445.8522352061207),
#  (452.5362137451162, 408.91570192186214),
#  (435.2472507449276, 431.69652561632506),
#  (118.81460431377013, 419.6698738128035),
#  (118.47327018045863, 46.50573072215636),
#  (234.1075759305495, 72.70603247642543),
#  (233.73688349810416, 186.65988819496886),
#  (458.59749232449, 350.6190667630694),
#  (77.02995589672673, 267.54589351640453),
#  (36.1665898652187, 459.7519794781712),
#  (254.1222118296041, 208.02636248368862),
#  (241.17759651410128, 35.61364036742687),
#  (420.0034622866428, 380.7293094021076),
#  (123.83865274004472, 357.30099927830236),
#  (199.25359894459106, 384.8563392164878),
#  (164.1918452436702, 172.31673762076792),
#  (189.22567414554288, 184.18813506804239),
#  (460.4789102047546, 386.43382000911464),
#  (27.403387405473687, 468.9249200319915),
#  (437.4266256699603, 382.57173314010515),
#  (306.0881317572699, 294.4609320583499),
#  (246.51932301387293, 474.3618177882792),
#  (382.4685916400545, 431.92575447701904),
#  (342.02195978912664, 202.86606576586053),
#  (426.17800916653516, 9.095903501727676),
#  (31.40367556947748, 349.45145584054336),
#  (106.05670473451607, 203.86773658903118),
#  (384.9893703573729, 28.170267151730656),
#  (310.2532267644478, 146.23164223356244),
#  (252.09039943648534, 31.983441953184865),
#  (226.052088301266, 483.84919004364764),
#  (138.424663540573, 419.65970228569074),
#  (174.36645587741015, 220.38938195982328),
#  (89.71244880381377, 272.30313413294584),
#  (247.19573903238424, 263.9451930121178),
#  (320.1011974145813, 62.01767668046687),
#  (248.7835119591965, 445.9870113946229),
#  (170.86606898439058, 136.0145915832517),
#  (335.0620330025912, 299.0886522774581),
#  (207.52193632637136, 139.72469261295745),
#  (177.28726885474785, 421.97117894563934),
#  (205.02235423937012, 47.66144252407389),
#  (310.53991805347175, 118.20469210269758),
#  (470.8759806235422, 341.01282420736754),
#  (453.51663091214857, 346.51785409394654),
#  (67.97897915792933, 93.10436697841334),
#  (316.09279648373956, 353.02365037677106),
#  (261.81480004638024, 442.24484060167987),
#  (162.14785376549028, 373.58482859076145),
#  (91.10150774728852, 343.6194102996226),
#  (260.2499983262412, 0.28431487475022443),
#  (408.50257369319735, 331.9315035482495),
#  (238.84828940131712, 431.44563767197195),
#  (128.96686475929334, 47.85563488019085),
#  (75.88979549731435, 49.882441689660325),
#  (307.3210309553967, 128.45983217670653),
#  (452.4391237804581, 159.37101462185788),
#  (85.73681203321058, 104.67216190866641),
#  (177.36798173547785, 100.46771247666436),
#  (260.85822441146144, 220.54612131150225),
#  (409.2929388543938, 58.44494668239753),
#  (169.0112335593521, 127.29701276623767),
#  (35.47093454619619, 355.7179252136478),
#  (13.597472664798023, 489.1236922792713),
#  (130.6498257973412, 358.26952696674965),
#  (91.3230638987008, 398.98455293408614),
#  (0.014017826350354312, 484.20078576477385),
#  (219.30774328099398, 141.83933953360116),
#  (153.46869176699954, 138.53099716194578),
#  (334.32755649965844, 435.370172925589),
#  (466.2089166689129, 239.2387892302124),
#  (358.87418033117814, 406.9729233780221),
#  (288.28548038343047, 349.158995998866),
#  (191.58960896311632, 240.58411050246593),
#  (101.53391797522832, 313.0204581324919),
#  (266.5015763340526, 446.1917002433552),
#  (345.63790983315226, 386.76549942511974),
#  (259.08956821238235, 135.51662406920028),
#  (299.99412213523226, 12.904867600564863),
#  (113.90665775768447, 24.184541338397814),
#  (218.1021418127042, 249.7807704965213),
#  (437.66938286929775, 456.13298972245514),
#  (166.427936758804, 473.74332872891506),
#  (189.82289631288478, 35.652361297528635),
#  (314.4547879099299, 160.0734563606993),
#  (243.50106785522772, 160.7477346350919),
#  (187.94988148094342, 211.17377012091427),
#  (33.23931853054507, 117.3587974148056),
#  (296.96274993586593, 72.84354764298234),
#  (239.3528236317188, 242.24944988160897),
#  (231.84244436894448, 383.4187303206192),
#  (256.7217666422235, 485.49515339003443),
#  (155.32496721477992, 43.47275781799104),
#  (81.08966332300666, 192.5044524351668),
#  (261.94472257199175, 343.3907758067711),
#  (158.32665437392126, 403.394805343268),
#  (101.39625037318527, 138.6697968349302),
#  (365.56727722970214, 135.16505605826623),
#  (70.13217194806015, 401.3186368922818),
#  (268.90266917567084, 348.8587675818032),
#  (172.17734351296946, 453.4862043820544),
#  (205.21294596115888, 20.175294602760463),
#  (290.5082847790115, 68.32744867158186),
#  (269.1859678030841, 17.066246977545052),
#  (403.59503754601093, 172.1068411251812),
#  (139.20179246629255, 429.60061228651904),
#  (444.7682773677164, 311.39973911381054),
#  (190.8983579581121, 78.61128444994769),
#  (397.03757706038164, 372.2845574355698),
#  (130.0795387287441, 471.5229136004686),
#  (228.66309997189342, 205.01349580255624),
#  (449.4127039634942, 462.91074879731724),
#  (56.12517938269132, 208.35374734322716),
#  (102.08526171587847, 286.83429297668454),
#  (135.9420912357187, 44.45205660251489),
#  (22.048754131937613, 363.864062831189),
#  (298.3779766129657, 241.10426038147216),
#  (55.21565893193191, 498.1783848408715),
#  (478.2623794843124, 140.50550386821297),
#  (81.52509472891217, 273.1466750345848),
#  (385.34185701677, 101.8825520707105),
#  (100.07213699667673, 34.99619685607275),
#  (154.96200270757348, 26.19008572452419),
#  (201.6246852116345, 326.4204206002151),
#  (233.26658560507224, 114.22444849512704),
#  (285.9300343522159, 107.78401649750491),
#  (217.8337037444014, 184.2893745991515),
#  (404.0520440018958, 393.1209299021559),
#  (29.822828542249855, 441.01607596025724),
#  (318.5786314833395, 212.5625960781743),
#  (332.243336116961, 102.15735515361601),
#  (339.56491796623635, 485.16919735794744),
#  (260.7292054615506, 340.99624652868863),
#  (82.28554743808718, 265.69731588544596),
#  (227.39977107077956, 251.28918773953802),
#  (84.89694902746193, 134.91116417715017),
#  (301.16656408602046, 257.18913449270525),
#  (294.0213107371338, 334.43173311525095),
#  (251.85080127312798, 428.2044009018684),
#  (409.4105454729707, 87.51716687998129),
#  (176.24522649503083, 289.39221916398577),
#  (129.7347731760849, 143.72684898176757),
#  (250.1539352349135, 268.9102734694138),
#  (126.65359653503606, 109.05658443950684),
#  (403.89861728040245, 192.52334640468598),
#  (240.66024701034854, 431.3209341169305),
#  (259.7751159748735, 389.3811287286794),
#  (61.03557894589835, 454.4168104505717),
#  (341.0724745016179, 241.2549809202833),
#  (386.6730858169068, 57.576495728403785),
#  (466.12601628849734, 245.5575700320171),
#  (219.00988340458565, 17.612835226370528),
#  (23.326593437469327, 413.65756053706275),
#  (299.811064277806, 2.5030172234769554),
#  (236.6767137232917, 405.63116243668003),
#  (459.18710473685104, 417.0608708858131),
#  (233.65710807951382, 159.56597490568635),
#  (271.48322417061627, 48.151681287069984),
#  (96.84025921246968, 315.11398141357404),
#  (153.394756668217, 56.75195790418858),
#  (132.7722197996447, 88.25577653629757),
#  (75.83002961997772, 398.9529117249938),
#  (370.8993038954821, 30.273849457951087),
#  (448.0332861225881, 182.00342523468242),
#  (121.00157139222705, 375.3188384224963),
#  (438.9456909359592, 178.6905197260908),
#  (285.50194940620383, 156.43198731391766),
#  (88.2838297791337, 48.62914637763438),
#  (194.5467633258902, 26.29539828921168),
#  (344.3880766566195, 44.70337241273026),
#  (448.5989330790937, 269.55786831206996),
#  (103.50532535934649, 335.77761649410587),
#  (454.6204103596019, 18.238087123696122),
#  (449.32219344888136, 149.50833767161743),
#  (282.53807008495187, 278.5719850835663),
#  (443.1993051241556, 193.11766112058586),
#  (294.1122195841235, 40.42725387252166),
#  (353.47320797726417, 277.89527141340477),
#  (361.8597637077763, 284.7805777132733),
#  (405.62434005654484, 356.6237026848888),
#  (328.4805195002632, 376.33054427445444),
#  (404.3827874628514, 42.418071088023204),
#  (84.76056222861982, 54.91893541782833),
#  (153.11449428243546, 412.87831256180607),
#  (200.9390269103908, 155.24863760026793),
#  (312.6352905086012, 408.44133497512234),
#  (44.01394497690761, 417.3244513295055),
#  (332.9232004878797, 267.67407325708723),
#  (215.29226965016633, 14.24465117779089),
#  (213.052027948095, 223.6745715184624),
#  (260.56082201659103, 282.350776979679),
#  (79.73905221271389, 438.93742548083253),
#  (229.2386500570338, 226.9852461019216),
#  (304.7454829622466, 392.3551783308793),
#  (37.81628192462385, 382.3727624660007),
#  (167.39389767780557, 362.0626158669254),
#  (172.1629292091274, 71.57026470866562),
#  (179.45336987051496, 183.7101795945888),
#  (247.62096686969753, 264.27585187591745),
#  (183.7782744878983, 38.547145224477),
#  (51.49406852733524, 219.85663902875564),
#  (425.93444582047425, 418.51457981139424),
#  (62.616324716266014, 337.56225337862486),
#  (285.93454094969866, 388.8940694728048),
#  (173.40813522658468, 425.29955318803695),
#  (48.238867851373485, 7.641976621608981),
#  (362.98264346297344, 161.48479387698194),
#  (13.673756626431128, 132.0576404217028),
#  (88.52955697395942, 56.55975219932774),
#  (452.9864735610461, 74.26923727255574),
#  (247.41507741644952, 456.1372818560294),
#  (204.44995621666328, 1.185323783749137),
#  (463.6118631310527, 110.79016969048999),
#  (402.69705718611226, 237.98671999688176),
#  (428.07797103676495, 340.6248314286466),
#  (451.1952626969661, 450.9107511268569),
#  (31.99632102229831, 77.63548785663926),
#  (321.9059966059542, 75.36048484009234),
#  (293.86956640090614, 158.3248216066525),
#  (350.43782708294685, 340.34047396845676),
#  (122.98160016958752, 237.58937370291588),
#  (237.24874881898617, 309.51425632657333),
#  (63.589819291119895, 86.20664527988737),
#  (233.18245342535985, 37.89815051140921),
#  (43.004000267053506, 340.2805413268226),
#  (357.80178846886264, 73.50484437626848),
#  (328.409978825817, 29.230469910106805),
#  (42.966551174598706, 59.40084007738544),
#  (418.2146112443521, 439.8044742603327),
#  (113.7634013531118, 254.01425506163912),
#  (66.89361326208426, 95.05420596280695),
#  (416.5224576362382, 266.3839943198102),
#  (174.78995879316454, 361.137296281186),
#  (144.95552482109125, 239.55464849013774),
#  (328.19240359577907, 157.80025399775926),
#  (135.42527430303562, 454.51425692587236),
#  (207.1770449726547, 495.41712511551754),
#  (392.25510856455315, 398.0877093802668),
#  (372.2146542164688, 462.6913336905992),
#  (60.230616284399204, 108.60867090013897),
#  (69.47593628797351, 121.4140025928374),
#  (385.54268815083964, 104.6582931877964),
#  (461.56848588007256, 259.4934373732671),
#  (329.9036140689661, 417.1596916839314),
#  (387.50497222038933, 364.2073244186905),
#  (30.955646222247175, 430.6146334345356),
#  (206.29874822384204, 139.41047590313087),
#  (407.9277600218187, 49.063564744065204),
#  (434.36967460000307, 32.46992617991401),
#  (318.1774252662521, 489.65766576336165),
#  (144.1250866594964, 24.841202150660102),
#  (381.6647189571011, 485.4136255079756),
#  (0.5421834844121243, 242.68986567450273),
#  (305.854104156779, 373.91530328194074),
#  (179.46970356940543, 273.57824664303337)]

# %% [markdown]
# ### 1b. Implement `best_candidate_sampling`

# %% [markdown]
# The `best_candidate_sampling` function should produce `n_samples` sample points randomly distributed over the sample domain. See lecture slides for details and pseudo-code. Hint: The `best_candidate` function here corresponds to the BEST-CANDIDATE-SAMPLE function in the slides, which generates a single new sample.

# %%
def best_candidate_sampling(image, n_samples, n_candidates):
    samples = []
    for i in range(n_samples):
        samples.append(best_candidate(image, samples, n_candidates))
    return samples

def best_candidate(image, samples, n_candidates):
    
    # dimensions is a tuple of width and height
    dimensions = image.shape[:2]
    
    for i in range(1, n_candidates):
        c = uniform_sample(dimensions[0], dimensions[1])
        (index, d) = closest_index(samples, c)
        if d > best_distance:
            best_distance = d
            best_candidate = c
    return best_candidate

samples_bc = best_candidate_sampling(image, 685, 10)
# Out:
# (204.42301468832, 142.86580415860828)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-e899315530c5> in <module>()
#      19     return best_candidate
#      20
# ---> 21 samples_bc = best_candidate_sampling(image, 685, 10)
#
# <ipython-input-23-e899315530c5> in best_candidate_sampling(image, n_samples, n_candidates)
#       2     samples = []
#       3     for i in range(n_samples):
# ----> 4         samples.append(best_candidate(image, samples, n_candidates))
#       5     return samples
#       6
#
# <ipython-input-23-e899315530c5> in best_candidate(image, samples, n_candidates)
#      13         c = uniform_sample(dimensions[0], dimensions[1])
#      14         print(c)
# ---> 15         (index, d) = closest_index(samples, c)
#      16         if d > best_distance:
#      17             best_distance = d
#
# <ipython-input-1-c21126d61949> in closest_index(sample_points, indices)
#      31     test at. Output is array of indices and distances.
#      32     """
# ---> 33     kdtree = KDTree(sample_points)
#      34     distance, index = kdtree.query(indices)
#      35     return index, distance
#
# scipy/spatial/ckdtree.pyx in scipy.spatial.ckdtree.cKDTree.__init__ (scipy/spatial/ckdtree.cxx:5147)()
#
# ValueError: Buffer has wrong number of dimensions (expected 2, got 1)

# %% [markdown]
# ### 1c. Implement `poison_disc_sampling`

# %% [markdown]
# The `poison_disc_sampling` function should produce sample points randomly distributed over the sample domain with a minimum distance of `radius`. See lecture slides and [Bridson's original paper](https://www.cs.ubc.ca/~rbridson/docs/bridson-siggraph07-poissondisk.pdf) for details.

# %%
def poison_disc_sampling(image, radius, n_candidates):
    # complete function without changing signature
    pass

# %% [markdown]
# ### Image sampling

# %% [markdown]
# The following cells are for testing and visualisation of your sampling methods.

# %% [markdown]
# #### Load test image

# %%
#image= load_image('./brain.png')
#image = load_image('./face.png')
#image = load_image('./lighthouse.png')
image = load_image('./mandrill.png')
#image = load_image('./parrots.png')
#image = load_image('./starry-night.png')
#image = load_image('./synth.png')
plt.imshow(image)

# %% [markdown]
# #### Generate random samples

# %%
#less samples - good for debugging
samples_uni = uniform_sampling(image, 685)
samples_bc = best_candidate_sampling(image, 685, 10)
samples_pd = poison_disc_sampling(image, 15, 30)

#more samples - looks better
#samples_uni = uniform_sampling(image, 2000)
#samples_bc = best_candidate_sampling(image, 2000, 10)
#samples_pd = poison_disc_sampling(image, 10, 30)

# %% [markdown]
# #### Plot samples

# %%
fig, axs = plt.subplots(1, 3, figsize=(18,5))
# [:,0] is access to the first column, [:, 1] the second
axs[0].scatter(samples_uni[:,0], samples_uni[:,1], marker='x')
axs[0].set_title('Uniform Sampling')
axs[1].scatter(samples_bc[:,0], samples_bc[:,1], marker='x')
axs[1].set_title('Best-Candidate Sampling')
axs[2].scatter(samples_pd[:,0], samples_pd[:,1], marker='x')
axs[2].set_title('Poison-Disc Sampling')
plt.show()

# %% [markdown]
# #### Resample images using random samples

# %%
image_uni = resample_image(image, samples_uni)
image_bc = resample_image(image, samples_bc)
image_pd = resample_image(image, samples_pd)

# %% [markdown]
# #### Plot images

# %%
fig, axs = plt.subplots(1, 4, figsize=(15,3))
axs[0].imshow(image)
axs[0].set_title('Original')
axs[1].imshow(image_uni)
axs[1].set_title('Uniform Sampling')
axs[2].imshow(image_bc)
axs[2].set_title('Best-Candidate Sampling')
axs[3].imshow(image_pd)
axs[3].set_title('Poison-Disc Sampling')
plt.show()

# %% [markdown]
# ### 1d. Implement `distance_map` for colouring image points according to their distance to sample points

# %% [markdown]
# The `distance_map` function should generate an image where each pixel intensity is set to the distance to the closest sample point. Hint: You might want to check out the `resample_image` function provided above for guidance.

# %%
def distance_map(image, sample_points):
    # complete function without changing signature
    pass

# %% [markdown]
# #### Generate distance maps using random samples

# %%
distmap_uni = distance_map(image, samples_uni)
distmap_bc = distance_map(image, samples_bc)
distmap_pd = distance_map(image, samples_pd)

# %% [markdown]
# #### Plot distance maps

# %%
fig, axs = plt.subplots(1, 3, figsize=(18,5))
axs[0].imshow(distmap_uni)
axs[0].set_title('Uniform Sampling')
axs[1].imshow(distmap_bc)
axs[1].set_title('Best-Candidate Sampling')
axs[2].imshow(distmap_pd)
axs[2].set_title('Poison-Disc Sampling')
plt.show()
